# %%
import matplotlib.pyplot as plt

# Data
models = ['Perioratt', 'Autocorr','Probsparse','Logsparse']
metrics = ['24', '48', '96', '192', '336']
mae_peri = [0.434,0.532,0.625,0.708,0.733]
mse_peri = [0.468,0.617,0.733,0.829,0.927]
mae_values_auto = [0.465,0.587,0.654,0.722,0.761]
mse_values_auto = [0.478,0.678,0.786,0.882,0.953]
mae_values_probsparse = [0.483,0.623,0.698,0.758,0.774]
mse_values_probsparse = [0.485,0.716,0.824,0.87,0.982]
mae_values_logsparse = [0.497,0.635,0.692,0.767,0.846]
mse_values_logsparse = [0.501,0.724,0.813,0.88,1.038]


plt.plot(metrics,mae_peri, marker='o',color='red', label='MAE-Perioratt')
plt.plot(metrics, mae_values_auto, marker='o', color='orange',label='MAE-Auto')
plt.plot(metrics,mae_values_probsparse, marker='o',color='blue', label='MAE-Probatt')
plt.plot(metrics, mae_values_logsparse, marker='o', color='green',label='MAE-Logsparse')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MAE score",fontsize=14)
plt.title("Attention ablation study on ETTh1",fontsize=14)

plt.legend(['MAE-Perioratt', 'MAE-Autocorr','MAE-Probsparse','MAE-Logsparse'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('ETTh1-Att ablation-MAE.pdf',format='pdf')
plt.show()

plt.plot(metrics,mse_peri, marker='o',color='red', label='MSE-Perioratt')
plt.plot(metrics, mse_values_auto, marker='o', color='orange',label='MSE-Auto')
plt.plot(metrics,mse_values_probsparse, marker='o',color='blue', label='MSE-Probatt')
plt.plot(metrics, mse_values_logsparse, marker='o', color='green',label='MSE-Logsparse')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MSE score",fontsize=14)
plt.title("Attention ablation study on ETTh1",fontsize=14)

plt.legend(['MSE-Perioratt', 'MSE-Autocorr','MSE-Probsparse','MSE-Logsparse'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('ETTh1-Att ablation-MSE.pdf',format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
# Data
models = ['Perioratt', 'Autocorr','Probsparse','Logsparse']
metrics = ['24', '48', '96', '192', '336']
mae_peri = [0.325,0.44,0.485,0.541,0.587]
mse_peri = [0.287,0.382,0.47,0.528,0.594]
mae_values_auto = [0.354,0.487,0.539,0.623,0.66]
mse_values_auto = [0.347,0.476,0.513,0.584,0.637]
mae_values_probsparse = [0.446,0.521,0.576,0.649,0.672]
mse_values_probsparse = [0.385,0.516,0.532,0.61,0.649]
mae_values_logsparse = [0.463,0.538,0.584,0.667,0.68]
mse_values_logsparse = [0.396,0.524,0.551,0.635,0.664]


plt.plot(metrics,mae_peri, marker='o',color='red', label='MAE-Perioratt')
plt.plot(metrics, mae_values_auto, marker='o', color='orange',label='MAE-Auto')
plt.plot(metrics,mae_values_probsparse, marker='o',color='blue', label='MAE-Probatt')
plt.plot(metrics, mae_values_logsparse, marker='o', color='green',label='MAE-Logsparse')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MAE score",fontsize=14)
plt.title("Attention ablation study on NDBC",fontsize=14)

plt.legend(['MAE-Perioratt', 'MAE-Autocorr','MAE-Probsparse','MAE-Logsparse'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('NDBC-Att ablation-MAE.pdf',format='pdf')
plt.show()

plt.plot(metrics,mse_peri, marker='o',color='red', label='MSE-Perioratt')
plt.plot(metrics, mse_values_auto, marker='o', color='orange',label='MSE-Auto')
plt.plot(metrics,mse_values_probsparse, marker='o',color='blue', label='MSE-Probatt')
plt.plot(metrics, mse_values_logsparse, marker='o', color='green',label='MSE-Logsparse')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MSE score",fontsize=14)
plt.title("Attention ablation study on NDBC",fontsize=14)

plt.legend(['MSE-Perioratt', 'MSE-Autocorr','MSE-Probsparse','MSE-Logsparse'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('NDBC-Att ablation-MSE.pdf',format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
models = ['Decom', 'Enc_Decom','Not_Decom']
metrics = ['24', '48', '96', '192', '336']
mae_periodic = [0.434,0.532,0.625,0.708,0.733]
mse_periodic = [0.468,0.617,0.733,0.829,0.927]
mae_Enc_Decom = [0.486,0.559,0.684,0.749,0.761]
mse_Enc_Decom = [0.538,0.632,0.783,0.862,0.985]
mae_Not_Decom = [0.513,0.597,0.731,0.805,0.849]
mse_Not_Decom = [0.586,0.672,0.798,0.934,1.126]

plt.plot(metrics,mae_periodic, marker='o',color='red', label='MAE-Decom')
plt.plot(metrics, mae_Enc_Decom, marker='o', color='orange',label='MAE-Enc_Decom')
plt.plot(metrics,mae_Not_Decom, marker='o',color='blue', label='MAE-Not_Decom')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MAE score",fontsize=14)
plt.title("Decomposition ablation study on ETTh1",fontsize=14)

plt.legend(['MAE-Decom', 'MAE-Enc_Decom','MAE-Not_Decom'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('ETTh1-Decomp ablation-MAE.pdf',format='pdf')
plt.show()


plt.plot(metrics,mse_periodic, marker='o',color='red', label='MSE-Decom')
plt.plot(metrics, mse_Enc_Decom, marker='o', color='orange',label='MSE-Enc_Decom')
plt.plot(metrics,mse_Not_Decom, marker='o',color='blue', label='MSE-Not_Decom')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MSE score",fontsize=14)
plt.title("Decomposition ablation study on ETTh1",fontsize=14)

plt.legend(['MSE-Decom', 'MSE-Enc_Decom','MSE-Not_Decom'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('ETTh1-Decomp ablation-MSE.pdf',format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
models = ['Decom', 'Enc_Decom','Not_Decom']
metrics = ['24', '48', '96', '192', '336']
mae_periodic = [0.325,0.44,0.485,0.541,0.587]
mse_periodic = [0.287,0.382,0.47,0.528,0.594]
mae_Enc_Decom = [0.358,0.476,0.532,0.579,0.637]
mse_Enc_Decom = [0.321,0.425,0.546,0.578,0.659]
mae_Not_Decom = [0.428,0.521,0.572,0.624,0.683]
mse_Not_Decom = [0.345,0.457,0.598,0.663,0.739]


plt.plot(metrics,mae_periodic, marker='o',color='red', label='MAE-Decom')
plt.plot(metrics, mae_Enc_Decom, marker='o', color='orange',label='MAE-Enc_Decom')
plt.plot(metrics,mae_Not_Decom, marker='o',color='blue', label='MAE-Not_Decom')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MAE score",fontsize=14)
plt.title("Decomposition ablation study on NDBC",fontsize=14)

plt.legend(['MAE-Decom', 'MAE-Enc_Decom','MAE-Not_Decom'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('NDBC-Decomp ablation-MAE.pdf',format='pdf')
plt.show()


plt.plot(metrics,mse_periodic, marker='o',color='red', label='MSE-Decom')
plt.plot(metrics, mse_Enc_Decom, marker='o', color='orange',label='MSE-Enc_Decom')
plt.plot(metrics,mse_Not_Decom, marker='o',color='blue', label='MSE-Not_Decom')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MSE score",fontsize=14)
plt.title("Decomposition ablation study on NDBC",fontsize=14)

plt.legend(['MSE-Decom', 'MSE-Enc_Decom','MSE-Not_Decom'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('NDBC-Decomp ablation-MSE.pdf',format='pdf')
plt.show()

# %%
#CDE Ablation study on ETTh1
#Try two y-axis.

import matplotlib.pyplot as plt

# Data
models = ['Periormer-CDE', 'Periormer-ODE','Periormer-None']
metrics = ['24', '48', '96', '192', '336']
mae_CDE = [0.437,0.538,0.621,0.701,0.726]
mae_ODE = [0.44,0.544,0.621,0.705,0.726]
mae_None = [0.455,0.553,0.658,0.724,0.726]
mse_CDE = [0.466,0.609,0.733,0.814,0.938]
mse_ODE = [0.466,0.624,0.733,0.816,0.936]
mse_None = [0.472,0.638,0.77,0.823,0.957]

fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.plot(metrics,mae_CDE, marker='o',color='red', label='MAE-Periormer-CDE')
ax1.plot(metrics, mae_ODE, marker='o', color='orange',label='MAE-Periormer-ODE')
ax1.plot(metrics, mae_None, marker='o', color='blue',label='MAE-Periormer-None')
ax1.set_xlabel("Prediction length",fontsize=14)
ax1.set_ylabel("MAE score",fontsize=14)
ax1.set_title("CDE ablation study on ETTh1",fontsize=14)

ax2=ax1.twinx()

ax2.plot(metrics, mse_ODE, marker='*',color='black', label='MSE-Periormer-ODE')
ax2.plot(metrics, mse_CDE,marker='*',color='yellow',  label='MSE-Periormer-CDE')
ax2.plot(metrics, mse_None, marker='*', color='grey',label='MSE-Periormer-None')
ax2.set_ylabel("MSE score",fontsize=14)
fig.legend(['MAE-Periormer-CDE','MAE-Periormer-ODE','MAE-Periormer-None','MSE-Periormer-CDE','MSE-Periormer-ODE','MSE-Periormer-None'],loc='lower right',bbox_to_anchor=(0.9,0.1),prop={'size': 12})
fig.savefig('ETTh1-CDE ablation.pdf',format='pdf')
plt.show()

# %%
#CDE Ablation study on ETTh1
#Try two y-axis.

import matplotlib.pyplot as plt

# Data
models = ['Periormer-CDE', 'Periormer-ODE','Periormer-None']
metrics = ['24', '48', '96', '192', '336']
mae_CDE = [0.327,0.438,0.489,0.538,0.585]
mse_CDE = [0.289,0.423,0.472,0.524,0.603]
mae_None = [0.354,0.487,0.523,0.576,0.621]
mse_None = [0.297,0.446,0.542,0.559,0.637]
mae_ODE = [0.336,0.461,0.495,0.556,0.593]
mse_ODE = [0.297,0.429,0.479,0.531,0.607]
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.plot(metrics,mae_CDE, marker='o',color='red', label='MAE-Periormer-CDE')
ax1.plot(metrics, mae_ODE, marker='o', color='orange',label='MAE-Periormer-ODE')
ax1.plot(metrics, mae_None, marker='o', color='blue',label='MAE-Periormer-None')
ax1.set_xlabel("Prediction length",fontsize=14)
ax1.set_ylabel("MAE score",fontsize=14)
ax1.set_title("CDE ablation study on NDBC",fontsize=14)

ax2=ax1.twinx()

ax2.plot(metrics, mse_ODE, marker='*',color='black', label='MSE-Periormer-ODE')
ax2.plot(metrics, mse_CDE,marker='*',color='yellow',  label='MSE-Periormer-CDE')
ax2.plot(metrics, mse_None, marker='*', color='grey',label='MSE-Periormer-None')
ax2.set_ylabel("MSE score",fontsize=14)
fig.legend(['MAE-Periormer-CDE','MAE-Periormer-ODE','MAE-Periormer-None','MSE-Periormer-CDE','MSE-Periormer-ODE','MSE-Periormer-None'],loc='lower right',bbox_to_anchor=(0.9,0.1),prop={'size': 12})
fig.savefig('NDBC-CDE ablation.pdf',format='pdf')
plt.show()

# %%
#Time encoding ablation study on ETTh1
#Try two y-axis.

import matplotlib.pyplot as plt

# Data
models = ['Periormer-IE', 'Periormer-Pos']
metrics = ['24', '48', '96', '192', '336']
mae_IE = [0.434,0.532,0.625,0.708,0.733]
mse_IE = [0.468,0.617,0.733,0.829,0.927]
mae_Pos = [0.444,0.571,0.646,0.729,0.743]
mse_Pos = [0.481,0.632,0.756,0.848,1.014]
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.plot(metrics,mae_IE, marker='o',color='red', label='MAE-Periormer-IE')
ax1.plot(metrics, mae_Pos, marker='o', color='orange',label='MAE-Periormer-Pos')
ax1.set_ylabel("MAE score",fontsize=14)
ax1.set_xlabel("Prediction length",fontsize=14)
ax1.set_title("Time encoding ablation study on ETTh1")

ax2=ax1.twinx()
ax2.plot(metrics, mse_IE,color='black', marker='*', label='MSE-Periormer-IE')
ax2.plot(metrics, mse_Pos, color='yellow',marker='*', label='MSE-Periormer-Pos')
ax2.set_ylabel("MSE score",fontsize=14)
fig.legend(['MAE-Periormer-IE','MAE-Periormer-Pos','MSE-Periormer-IE','MSE-Periormer-Pos'],loc='upper left',bbox_to_anchor=(0.13,0.88),prop={'size': 12})
fig.savefig('ETTh1-Time encoding ablation.pdf',format='pdf')
plt.show()

# %%
#Time encoding ablation study on NDBC
#Try two y-axis.

import matplotlib.pyplot as plt

# Data
models = ['Periormer-IE', 'Periormer-Pos']
metrics = ['24', '48', '96', '192', '336']
mae_IE = [0.325,0.44,0.485,0.541,0.587]
mse_IE = [0.287,0.382,0.47,0.528,0.594]
mae_Pos = [0.384,0.471,0.515,.591,0.625]
mse_Pos = [0.332, 0.439,0.506,0.574,0.643]

fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.plot(metrics,mae_IE, marker='o',color='red', label='MAE-Periormer-IE')
ax1.plot(metrics, mae_Pos, marker='o', color='orange',label='MAE-Periormer-Pos')
ax1.set_ylabel("MAE score",fontsize=14)
ax1.set_xlabel("Prediction length",fontsize=14)
ax1.set_title("Time encoding ablation study on NDBC")

ax2=ax1.twinx()
ax2.plot(metrics, mse_IE,color='black', marker='*', label='MSE-Periormer-IE')
ax2.plot(metrics, mse_Pos, color='yellow',marker='*', label='MSE-Periormer-Pos')
ax2.set_ylabel("MSE score",fontsize=14)
fig.legend(['MAE-Periormer-IE','MAE-Periormer-Pos','MSE-Periormer-IE','MSE-Periormer-Pos'],loc='upper left',bbox_to_anchor=(0.13,0.88),prop={'size': 12})
fig.savefig('NDBC-Time encoding ablation.pdf',format='pdf')
plt.show()

# %%
#Ablation study on Cross feature attention:ETTh1
import matplotlib.pyplot as plt

# Data
models = ['Periormer', 'Periormer-CFPA1','Periormer-CFPA2','Periormer-FWPA1','Periormer-FWPA2']
metrics = ['24', '48', '96', '192', '336']
mae_Periormer = [0.434,0.532,0.625, 0.708, 0.733, ]
mse_Periormer = [0.468,0.617,0.733,0.829,0.927]
mae_Periormer_CFPA1 = [0.463,0.574,0.651,0.734,0.769]
mse_Periormer_CFPA1 = [0.485,0.662,0.786,0.859,0.963]
mae_Periormer_CFPA2 = [0.472,0.583,0.654,0.745,0.783]
mse_Periormer_CFPA2 = [0.488,0.681,0.790,0.866,0.975]
mae_Periormer_FWPA1 =[0.489,0.608,0.638,0.764,0.816]
mse_Periormer_FWPA1 =[0.503,0.694,0.776,0.875,1.087]
mae_Periormer_FWPA2 =[0.514,0.612,0.690,0.796,0.838]
mse_Periormer_FWPA2 =[0.522 ,0.706 ,0.833,0.917,1.144]
plt.plot(metrics,mae_Periormer, marker='o',color='red', label='MAE-Periormer')
plt.plot(metrics, mae_Periormer_CFPA1, marker='o', color='orange',label='MAE-Periormer-CFPA1')
plt.plot(metrics,mae_Periormer_CFPA2, marker='o',color='blue', label='MAE-Periormer-CFPA2')
plt.plot(metrics,mae_Periormer_FWPA1, marker='o',color='green', label='MAE-Periormer-FWPA1')
plt.plot(metrics,mae_Periormer_FWPA2, marker='o',color='yellow', label='MAE-Periormer-FWPA2')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MAE score",fontsize=14)
plt.title("CFPA ablation study of ETTh1 on MAE",fontsize=14)

# plt.legend(['MAE-Periormer','MAE-Periormer-CFPA1', 'MAE-Periormer-CFPA2','MAE-Periormer-FWPA1','MAE-Periormer-FWPA2'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
plt.legend(['MAE-Periormer','MAE-Periormer-CFPA1', 'MAE-Periormer-CFPA2','MAE-Periormer-FWPA1','MAE-Periormer-FWPA2'],loc='lower right',prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('ETTh1-CFPA ablation-MAE.pdf',format='pdf')
plt.show()


plt.plot(metrics,mse_Periormer, marker='o',color='red', label='MSE-Periormer')
plt.plot(metrics, mse_Periormer_CFPA1, marker='o', color='orange',label='MSE-Periormer-CFPA1')
plt.plot(metrics,mse_Periormer_CFPA2, marker='o',color='blue', label='MSE-Periormer-CFPA2')
plt.plot(metrics,mse_Periormer_FWPA1, marker='o',color='green', label='MSE-Periormer-FWPA1')
plt.plot(metrics,mse_Periormer_FWPA2, marker='o',color='yellow', label='MSE-Periormer-FWPA2')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MSE score",fontsize=14)
plt.title("CFPA ablation study of ETTh1 on MSE",fontsize=14)
plt.legend(['MSE-Periormer','MSE-Periormer-CFPA1', 'MSE-Periormer-CFPA2','MSE-Periormer-FWPA1','MSE-Periormer-FWPA2'],loc='lower right',prop={'size': 12})
#plt.legend(['MSE-Periormer','MSE-Periormer-CFPA1', 'MSE-Periormer-CFPA2','MSE-Periormer-FWPA1','MSE-Periormer-FWPA2'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('ETTh1-CFPA ablation-MSE.pdf',format='pdf')
plt.show()

# %%
#Ablation study on Cross feature attention:NDBC
import matplotlib.pyplot as plt

# Data
models = ['Periormer', 'Periormer-CFPA1','Periormer-CFPA2','Periormer-FWPA1','Periormer-FWPA2']
metrics = ['24', '48', '96', '192', '336']
mae_Periormer = [0.325,0.440,0.485,0.541,0.587]
mse_Periormer = [0.287,0.382,0.470,0.528,0.594]
mae_Periormer_CFPA1 =[0.349,0.476,0.522,0.567,0.638]
mse_Periormer_CFPA1 = [0.301,0.418,0.496,0.540,0.629]
mae_Periormer_CFPA2 = [0.338,0.468,0.531,0.587,0.659]
mse_Periormer_CFPA2 = [0.289,0.397,.492,0.574,0.641]
mae_Periormer_FWPA1 =[0.362,0.493,.568,0.621,0.688]
mse_Periormer_FWPA1 =[0.301,0.425,0.532,0.607,0.674]
mae_Periormer_FWPA2 =[0.366,0.505,0.578,0.638,0.709]
mse_Periormer_FWPA2 =[0.307 ,0.435 ,0.539 ,0.622 ,0.693 ]
plt.plot(metrics,mae_Periormer, marker='o',color='red', label='MAE-Periormer')
plt.plot(metrics, mae_Periormer_CFPA1, marker='o', color='orange',label='MAE-Periormer-CFPA1')
plt.plot(metrics,mae_Periormer_CFPA2, marker='o',color='blue', label='MAE-Periormer-CFPA2')
plt.plot(metrics,mae_Periormer_FWPA1, marker='o',color='green', label='MAE-Periormer-FWPA1')
plt.plot(metrics,mae_Periormer_FWPA2, marker='o',color='yellow', label='MAE-Periormer-FWPA2')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MAE score",fontsize=14)
plt.title("CFPA ablation study of NDBC on MAE",fontsize=14)

# plt.legend(['MAE-Periormer','MAE-Periormer-CFPA1', 'MAE-Periormer-CFPA2','MAE-Periormer-FWPA1','MAE-Periormer-FWPA2'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
plt.legend(['MSE-Periormer','MSE-Periormer-CFPA1', 'MSE-Periormer-CFPA2','MSE-Periormer-FWPA1','MSE-Periormer-FWPA2'],loc='lower right',prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('NDBC-CFPA ablation-MAE.pdf',format='pdf')
plt.show()


plt.plot(metrics,mse_Periormer, marker='o',color='red', label='MSE-Periormer')
plt.plot(metrics, mse_Periormer_CFPA1, marker='o', color='orange',label='MSE-Periormer-CFPA1')
plt.plot(metrics,mse_Periormer_CFPA2, marker='o',color='blue', label='MSE-Periormer-CFPA2')
plt.plot(metrics,mse_Periormer_FWPA1, marker='o',color='green', label='MSE-Periormer-FWPA1')
plt.plot(metrics,mse_Periormer_FWPA2, marker='o',color='yellow', label='MSE-Periormer-FWPA2')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MSE score",fontsize=14)
plt.title("CFPA ablation study of NDBC on MSE",fontsize=14)
plt.legend(['MSE-Periormer','MSE-Periormer-CFPA1', 'MSE-Periormer-CFPA2','MSE-Periormer-FWPA1','MSE-Periormer-FWPA2'],loc='lower right',prop={'size': 12})
# plt.legend(['MSE-Periormer','MSE-Periormer-CFPA1', 'MSE-Periormer-CFPA2','MSE-Periormer-FWPA1','MSE-Periormer-FWPA2'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('NDBC-CFPA ablation-MSE.pdf',format='pdf')
plt.show()

# %%
#Sensitivity study of input length on ETTh1
import matplotlib.pyplot as plt

# Data
models = ['Periormer', 'FEDformer','Autoformer','Informer','LogTrans','Reformer']
metrics = [ '48', '96', '192', '336']
mae_Periormer = [0.654,0.621,0.618,0.609]
mse_Periormer = [0.764,0.733,0.726,0.71]
mae_FEDformer =[0.734,0.705,0.729,0.73]
mse_FEDformer = [0.868,0.823,0.854,0.854]
mae_Autoformer = [0.672,0.694,0.705,0.689,]
mse_Autoformer = [0.743,0.802,0.836,0.813]
mae_Informer=[0.683,0.718,0.697,0.734]
mse_Informer=[0.786,0.84,0.815,0.866]
mae_LogTrans =[0.806,0.823,0.859,0.815]
mse_LogTrans =[0.854,0.877,0.92,0.864]
mae_Reformer=[0.913,0.973,0.944,0.937]
mse_Reformer =[1.156,1.584,1.358,1.216]
plt.plot(metrics,mae_Periormer, marker='o',color='red', label='MAE-Periormer')
plt.plot(metrics, mae_FEDformer, marker='o', color='orange',label='MAE-FEDformer')
plt.plot(metrics,mae_Autoformer, marker='o',color='blue', label='MAE-Autoformer')
plt.plot(metrics,mae_Informer, marker='o',color='green', label='MAE-Informer')
plt.plot(metrics,mae_LogTrans, marker='o',color='yellow', label='MAE-LogTrans')
plt.plot(metrics,mae_Reformer, marker='o',color='pink', label='MAE-Reformer')
plt.xlabel("Input length",fontsize=14)
plt.ylabel("MAE score",fontsize=14)
plt.title("Input length sensitivity study of ETTh1 on MAE",fontsize=14)

plt.legend(['MAE-Periormer','MAE-FEDformer', 'MAE-Autoformer','MAE-Informer','MAE-LogTrans','MAE-Reformer'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
# plt.legend(['MSE-Periormer','MSE-Periormer-CFPA1', 'MSE-Periormer-CFPA2','MSE-Periormer-FWPA1','MSE-Periormer-FWPA2'],loc='lower right',prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.ylim(0.6,1.5)
plt.savefig('ETTh1-Input length sensitivity study-MAE.pdf',format='pdf')
plt.show()


plt.plot(metrics,mse_Periormer, marker='o',color='red', label='MSE-Periormer')
plt.plot(metrics, mse_FEDformer, marker='o', color='orange',label='MSE-FEDformer')
plt.plot(metrics,mse_Autoformer, marker='o',color='blue', label='MSE-Autoformer')
plt.plot(metrics,mse_Informer, marker='o',color='green', label='MSE-Informer')
plt.plot(metrics,mse_LogTrans, marker='o',color='yellow', label='MSE-LogTrans')
plt.plot(metrics,mse_Reformer, marker='o',color='pink', label='MSE-Reformer')
plt.xlabel("Input length",fontsize=14)
plt.ylabel("MSE score",fontsize=14)
plt.title("Input length sensitivity study of ETTh1 on MSE",fontsize=14)
plt.ylim(0.7,2.5)
plt.legend(['MSE-Periormer','MSE-FEDformer', 'MSE-Autoformer','MSE-Informer','MSE-LogTrans','MSE-Reformer'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
# plt.legend(['MSE-Periormer','MSE-Periormer-CFPA1', 'MSE-Periormer-CFPA2','MSE-Periormer-FWPA1','MSE-Periormer-FWPA2'],loc='lower right',prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('ETTh1-Input length sensitivity study-MSE.pdf',format='pdf')
plt.show()

# %%
#Sensitivity study of input length on NDBC
import matplotlib.pyplot as plt

# Data
models = ['Periormer', 'FEDformer','Autoformer','Informer','LogTrans','Reformer']
metrics = [ '48', '96', '192', '336']
mae_Periormer = [0.482,0.489,0.457,0.435]
mse_Periormer = [0.456,0.472,0.446,0.439]
mae_FEDformer =[0.569,0.586,0.592,0.598]
mse_FEDformer = [0.521,0.548,0.557,0.563]
mae_Autoformer = [0.612,0.597,0.584,0.614]
mse_Autoformer = [0.557,0.521,0.509,0.559]
mae_Informer=[0.546,0.534,0.592,0.614]
mse_Informer=[0.632,0.618,0.631,0.658]
mae_LogTrans =[0.533,0.526,0.542,0.585]
mse_LogTrans =[0.612,0.597,0.573,0.644]
mae_Reformer=[0.735,0.633,0.662,0.651]
mse_Reformer =[0.789,0.677,0.728,0.71]
plt.plot(metrics,mae_Periormer, marker='o',color='red', label='MAE-Periormer')
plt.plot(metrics,mae_FEDformer, marker='o', color='orange',label='MAE-FEDformer')
plt.plot(metrics,mae_Autoformer, marker='o',color='blue', label='MAE-Autoformer')
plt.plot(metrics,mae_Informer, marker='o',color='green', label='MAE-Informer')
plt.plot(metrics,mae_LogTrans, marker='o',color='yellow', label='MAE-LogTrans')
plt.plot(metrics,mae_Reformer, marker='o',color='pink', label='MAE-Reformer')
plt.xlabel("Input length",fontsize=14)
plt.ylabel("MAE score",fontsize=14)
plt.ylim(0.4,1.2)
plt.savefig('NDBC-Input length sensitivity study-MAE.pdf',format='pdf')
plt.title("Input length sensitivity study of NDBC on MAE",fontsize=14)
plt.legend(['MAE-Periormer','MAE-FEDformer', 'MAE-Autoformer','MAE-Informer','MAE-LogTrans','MAE-Reformer'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
# plt.legend(['MSE-Periormer','MSE-Periormer-CFPA1', 'MSE-Periormer-CFPA2','MSE-Periormer-FWPA1','MSE-Periormer-FWPA2'],loc='lower right',prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('NDBC-Input length sensitivity study-MAE.pdf',format='pdf')
plt.show()


plt.plot(metrics,mse_Periormer, marker='o',color='red', label='MSE-Periormer')
plt.plot(metrics, mse_FEDformer, marker='o', color='orange',label='MSE-FEDformer')
plt.plot(metrics,mse_Autoformer, marker='o',color='blue', label='MSE-Autoformer')
plt.plot(metrics,mse_Informer, marker='o',color='green', label='MSE-Informer')
plt.plot(metrics,mse_LogTrans, marker='o',color='yellow', label='MSE-LogTrans')
plt.plot(metrics,mse_Reformer, marker='o',color='pink', label='MSE-Reformer')
plt.xlabel("Input length",fontsize=14)
plt.ylabel("MSE score",fontsize=14)
plt.ylim(0.4,1.2)
plt.title("Input length sensitivity study of NDBC on MSE",fontsize=14)
plt.legend(['MSE-Periormer','MSE-FEDformer', 'MSE-Autoformer','MSE-Informer','MSE-LogTrans','MSE-Reformer'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
# plt.legend(['MSE-Periormer','MSE-Periormer-CFPA1', 'MSE-Periormer-CFPA2','MSE-Periormer-FWPA1','MSE-Periormer-FWPA2'],loc='lower right',prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('NDBC-Input length sensitivity study-MSE.pdf',format='pdf')
plt.show()

# %%
#Sensitivity study of embedding size on ETTh1
import matplotlib.pyplot as plt

# Data
models = ['Emb-128', 'Emb-256','Emb-512','Emb-1024','Emb-2048']
metrics = [ '24','48', '96', '192', '336']
mae_Emb_128 = [0.446,0.548,0.642,0.722,0.753]
mse_Emb_128 = [0.476,0.637,0.752,0.847,0.958]
mae_Emb_256 =[0.439,0.535,0.635,0.717,0.743]
mse_Emb_256 = [0.469,0.621,0.743,0.837,0.943]
mae_Emb_512 = [0.434,0.532,0.625,0.708,0.733]
mse_Emb_512 = [0.468,0.617,0.733,0.829,0.927]
mae_Emb_1024=[0.438,0.544,0.643,0.731,0.741]
mse_Emb_1024=[0.475,0.648,0.764,0.869,0.944]
mae_Emb_2048 =[0.434,0.526,0.634,0.724,0.743]
mse_Emb_2048 =[0.471,0.609,0.743,0.846,0.943]
plt.plot(metrics,mae_Emb_128, marker='o',color='red', label='Emb-128')
plt.plot(metrics,mae_Emb_256, marker='o', color='orange',label='Emb-256')
plt.plot(metrics,mae_Emb_512, marker='o',color='blue', label='Emb-512')
plt.plot(metrics,mae_Emb_1024, marker='o',color='green', label='Emb-1024')
plt.plot(metrics,mae_Emb_2048, marker='o',color='yellow', label='Emb-2048')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MAE score",fontsize=14)
plt.savefig('ETTh1-Embedding size sensitivity study-MAE.pdf',format='pdf')
plt.title("Embedding size sensitivity study of ETTh1 on MAE",fontsize=14)
plt.legend(['Emb-128','Emb-256','Emb-512','Emb-1024','Emb-2048'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
# plt.legend(['MSE-Periormer','MSE-Periormer-CFPA1', 'MSE-Periormer-CFPA2','MSE-Periormer-FWPA1','MSE-Periormer-FWPA2'],loc='lower right',prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('ETTh1-Embedding size sensitivity study-MAE.pdf',format='pdf')
plt.show()


plt.plot(metrics,mse_Emb_128, marker='o',color='red', label='Emb-128')
plt.plot(metrics,mse_Emb_256, marker='o', color='orange',label='Emb-256')
plt.plot(metrics,mse_Emb_512, marker='o',color='blue', label='Emb-512')
plt.plot(metrics,mse_Emb_1024, marker='o',color='green', label='Emb-1024')
plt.plot(metrics,mse_Emb_2048, marker='o',color='yellow', label='Emb-2048')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MSE score",fontsize=14)
plt.savefig('ETTh1-Embedding size sensitivity study-MSE.pdf',format='pdf')
plt.title("Embedding size sensitivity study of ETTh1 on MSE",fontsize=14)
plt.legend(['Emb-128','Emb-256','Emb-512','Emb-1024','Emb-2048'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
# plt.legend(['MSE-Periormer','MSE-Periormer-CFPA1', 'MSE-Periormer-CFPA2','MSE-Periormer-FWPA1','MSE-Periormer-FWPA2'],loc='lower right',prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('ETTh1-Embedding size sensitivity study-MSE.pdf',format='pdf')
plt.show()

# %%
#Sensitivity study of embedding size on NDBC
import matplotlib.pyplot as plt

# Data
models = ['Emb-128', 'Emb-256','Emb-512','Emb-1024','Emb-2048']
metrics = [ '24','48', '96', '192', '336']
mae_Emb_128 = [0.34,0.444,0.462,0.601,0.661]
mse_Emb_128 = [0.303,0.390,0.510,0.584,0.644]
mae_Emb_256 =[0.331,0.430,0.441,0.556,0.613]
mse_Emb_256 = [0.295,0.375,0.460,0.538,0.622]
mae_Emb_512 = [0.325,0.440,0.485,0.541,0.587]
mse_Emb_512 = [0.287,0.382,0.470,0.528,0.594]
mae_Emb_1024=[0.332,0.421,0.450,0.568,0.607]
mse_Emb_1024=[0.296,0.358,0.454,0.574,0.617]
mae_Emb_2048 =[0.339,0.452,0.501,0.548,0.628]
mse_Emb_2048 =[0.304,0.393,0.483,0.546,0.632]
plt.plot(metrics,mae_Emb_128, marker='o',color='red', label='Emb-128')
plt.plot(metrics,mae_Emb_256, marker='o', color='orange',label='Emb-256')
plt.plot(metrics,mae_Emb_512, marker='o',color='blue', label='Emb-512')
plt.plot(metrics,mae_Emb_1024, marker='o',color='green', label='Emb-1024')
plt.plot(metrics,mae_Emb_2048, marker='o',color='yellow', label='Emb-2048')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MAE score",fontsize=14)
plt.savefig('NDBC-Embedding size sensitivity study-MAE.pdf',format='pdf')
plt.title("Embedding size sensitivity study of NDBC on MAE",fontsize=14)
plt.legend(['Emb-128','Emb-256','Emb-512','Emb-1024','Emb-2048'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
# plt.legend(['MSE-Periormer','MSE-Periormer-CFPA1', 'MSE-Periormer-CFPA2','MSE-Periormer-FWPA1','MSE-Periormer-FWPA2'],loc='lower right',prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('NDBC-Embedding size sensitivity study-MAE.pdf',format='pdf')
plt.show()


plt.plot(metrics,mse_Emb_128, marker='o',color='red', label='Emb-128')
plt.plot(metrics,mse_Emb_256, marker='o', color='orange',label='Emb-256')
plt.plot(metrics,mse_Emb_512, marker='o',color='blue', label='Emb-512')
plt.plot(metrics,mse_Emb_1024, marker='o',color='green', label='Emb-1024')
plt.plot(metrics,mse_Emb_2048, marker='o',color='yellow', label='Emb-2048')
plt.xlabel("Prediction length",fontsize=14)
plt.ylabel("MSE score",fontsize=14)
plt.savefig('NDBC-Embedding size sensitivity study-MSE.pdf',format='pdf')
plt.title("Embedding size sensitivity study of NDBC on MSE",fontsize=14)
plt.legend(['Emb-128','Emb-256','Emb-512','Emb-1024','Emb-2048'],loc='upper left',bbox_to_anchor=(0.01,1),prop={'size': 12})
# plt.legend(['MSE-Periormer','MSE-Periormer-CFPA1', 'MSE-Periormer-CFPA2','MSE-Periormer-FWPA1','MSE-Periormer-FWPA2'],loc='lower right',prop={'size': 12})
plt.xticks(fontproperties='Times New Roman', size=14)
plt.yticks(fontproperties='Times New Roman', size=14)
plt.savefig('NDBC-Embedding size sensitivity study-MSE.pdf',format='pdf')
plt.show()

# %%
#Sensitivity study of R square on ETTh1

import matplotlib.pyplot as plt

# Data
models = ['R^2_60%', 'R^2_70%','R^2_80%','R^2_90%']
metrics = ['24', '48', '96', '192', '336']
mae_60= [0.459982712,
0.559123062,
0.661003875,
0.743523249,
0.782602814
]
mse_60 = [0.495908244,
0.650957459,
0.758654414,
0.871580829,
0.971207485
]
mae_70 = [0.446152,
0.5492368,
0.642375,
0.7210272,
0.74675841
]
mse_70 = [0.4791384,
0.6332271,
0.7467071,
0.849080204,
0.94503015
]
mae_80 = [0.434,
0.532,
0.625,
0.708,
0.733
]
mse_80 = [0.468,
0.617,
0.733,
0.829,
0.927
]
mae_90 = [0.426535627,
0.5392884,
0.619732276,
0.710832,
0.735205617
]
mse_90 = [0.461629513,
0.6249593,
0.730676449,
0.84558,
0.931658291
]
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.plot(metrics,mae_60, marker='o',color='red', label='R^2_60%')
ax1.plot(metrics, mae_70, marker='o', color='orange',label='R^2_70%')
ax1.plot(metrics,mae_80, marker='o',color='blue', label='R^2_80%')
ax1.plot(metrics, mae_90, marker='o', color='yellow',label='R^2_90%')
plt.ylim(0.4,1.3)
ax1.set_ylabel("MAE score",fontsize=14)
ax1.set_xlabel("Prediction length",fontsize=14)
ax1.set_title("R Square sensitivity study of ETTh1 on MAE")

ax2=ax1.twinx()
ax1.plot(metrics,mse_60, marker='*',color='red', label='R^2_60%')
ax1.plot(metrics, mse_70, marker='*', color='orange',label='R^2_70%')
ax1.plot(metrics,mse_80, marker='*',color='blue', label='R^2_80%')
ax1.plot(metrics, mse_90, marker='*', color='yellow',label='R^2_90%')
ax2.set_ylabel("MSE score",fontsize=14)
fig.legend(['R^2_60%-MAE','R^2_70%-MAE','R^2_80%-MAE','R^2_90%-MAE','R^2_60%-MSE','R^2_70%-MSE','R^2_80%-MSE','R^2_90%-MSE'],loc='upper left',bbox_to_anchor=(0.13,0.88),prop={'size': 12})
plt.ylim(0,1.7)
fig.savefig('ETTh1-R Square sensitivity study.pdf',format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
models = ['R^2_60%', 'R^2_70%','R^2_80%','R^2_90%']
metrics = ['24', '48', '96', '192', '336']
mae_60= [0.3384433,
0.46182136,
0.51054786,
0.562854236,
0.614966265
]
mse_60 = [0.308035665,
0.400546482,
0.49234004,
0.55148544,
0.621012744
]
mae_70 = [0.329225,
0.45188,
0.49761,
0.552902,
0.5987987
]
mse_70 = [0.297619,
0.393078,
0.47893,
0.540672,
0.604098
]
mae_80 = [0.325,
0.44,
0.485,
0.541,
0.587
]
mse_80 = [0.287,
0.382,
0.47,
0.528,
0.594
]
mae_90 = [0.324935013,
0.43912,
0.480912246,
0.543164,
0.588766299
]
mse_90 = [0.286942611,
0.3820764,
0.468510138,
0.53856,
0.596984925
]
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.plot(metrics,mae_60, marker='o',color='red', label='R^2_60%')
ax1.plot(metrics, mae_70, marker='o', color='orange',label='R^2_70%')
ax1.plot(metrics,mae_80, marker='o',color='blue', label='R^2_80%')
ax1.plot(metrics, mae_90, marker='o', color='yellow',label='R^2_90%')
ax1.set_ylabel("MAE score",fontsize=14)
ax1.set_xlabel("Prediction length",fontsize=14)
ax1.set_title("R Square sensitivity study of NDBC on MAE")

ax2=ax1.twinx()
ax1.plot(metrics,mse_60, marker='*',color='red', label='R^2_60%')
ax1.plot(metrics, mse_70, marker='*', color='orange',label='R^2_70%')
ax1.plot(metrics,mse_80, marker='*',color='blue', label='R^2_80%')
ax1.plot(metrics, mse_90, marker='*', color='yellow',label='R^2_90%')
ax2.set_ylabel("MSE score",fontsize=14)
# fig.legend(['R^2_60%-MAE','R^2_70%-MAE','R^2_80%-MAE','R^2_90%-MAE','R^2_60%-MSE','R^2_70%-MSE','R^2_80%-MSE','R^2_90%-MSE'],loc='upper left',bbox_to_anchor=(0.13,0.88),prop={'size': 12})
fig.legend(['R^2_60%-MAE','R^2_70%-MAE','R^2_80%-MAE','R^2_90%-MAE','R^2_60%-MSE','R^2_70%-MSE','R^2_80%-MSE','R^2_90%-MSE'],loc='lower right',bbox_to_anchor=(0.9,0.1),prop={'size': 12})
fig.savefig('NDBC-R Square sensitivity study.pdf',format='pdf')
plt.show()

# %%
#Training set running time on eight datasets
import matplotlib.pyplot as plt

# Data
models = ['Periormer', 'FEDformer', 'Autoformer', 'Informer', 'LogTrans', 'Reformer']
metrics = ['WTH', 'ETTh1', 'ETTm1', 'ETTm2', 'NDBC', 'Synthetic', 'Stock1', 'Stock2']
time_values_CDE_Periormer = [58.797,
37.489,
84.383,
84.812,
354.648,
16.37,
6.289,
5.978]
time_values_FEDformer = [54.326,
                         32.28,
                         68.845,
                         64.281,
                         288.712,
                         12.984,
                         6.264,
                         4.871
                         ]
time_values_Autoformer = [78.35,
                          42.37,
                          106.35,
                          108.74,
                          413.78,
                          17.35,
                          6.84,
                          6.27
                          ]
time_values_Informer = [56.48,
                        32.34,
                        78.83,
                        76.34,
                        286.37,
                        13.29,
                        6.12,
                        4.37,
                        ]
time_values_LogTrans = [51.23,
                        29.5,
                        62.74,
                        61.54,
                        274.32,
                        11.26,
                        5.57,
                        3.98
                        ]
time_values_Reformer = [62.78,
                        43.84,
                        95.66,
                        94.38,
                        398.43,
                        16.44,
                        6.77,
                        5.96
                        ]

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(metrics, time_values_CDE_Periormer, marker='o', color='red', label='Periormer')
ax1.scatter(metrics, time_values_FEDformer, marker='o', color='grey', label='FEDformer')
ax1.scatter(metrics, time_values_Autoformer, marker='o', color='orange', label='Autoformer')
ax1.scatter(metrics, time_values_Informer, marker='o', color='blue', label='Informer')
ax1.scatter(metrics, time_values_LogTrans, marker='o', color='green', label='LogTrans')
ax1.scatter(metrics, time_values_Reformer, marker='o', color='purple', label='Reformer')
ax1.set_ylabel("Time (s)",size=14)
ax1.set_xlabel("Dataset",size=14)
ax1.set_title("Training set running time each epoch on eight datasets")

#fig.legend(['MAE-Periormer', 'MAE-Autoformer','MAE-Informer','MAE-LogTrans','MAE-Reformer'],loc='upper right',bbox_to_anchor=(1.14,0.879))#bbox_to_anchor=(0.13,0.88))#bbox_to_anchor=(0.13,0.88))
fig.legend(['Periormer','FEDformer', 'Autoformer', 'Informer', 'LogTrans', 'Reformer'], loc='upper left',
           bbox_to_anchor=(0.13, 0.88),prop={'size': 12})
fig.savefig('Training set running time each epoch on eight datasets.pdf',format='pdf')
plt.show() #Sensitivity study of R square on NDBC

# %%
#Test set running time on eight datasets
import matplotlib.pyplot as plt

# Data
models = ['Periormer', 'FEDformer', 'Autoformer', 'Informer', 'LogTrans', 'Reformer']
metrics = ['WTH', 'ETTh1', 'ETTm1', 'ETTm2', 'NDBC', 'Synthetic', 'Stock1', 'Stock2']
time_values_CDE_Periormer = [2.897,
0.985,
4.336,
4.312,
12.325,
0.387,
0.054,
0.026]

time_values_FEDformer = [4.245,
1.259,
5.284,
5.064,
14.864,
0.668,
0.097,
0.064
                         ]
time_values_Autoformer = [4.427,
1.53,
6.752,
6.728,
20.086,
0.858,
0.112,
0.061    ]
time_values_Informer = [2.972,
1.04,
4.285,
4.185,
11.843,
0.362,
0.057,
0.024  ]
time_values_LogTrans = [3.241,
1.19,
4.786,
4.693,
14.325,
0.554,
0.078,
0.032 ]
time_values_Reformer = [4.932,
1.436,
5.537,
5.527,
16.468,
0.798,
0.106,
0.058]

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(metrics, time_values_CDE_Periormer, marker='o', color='red', label='Periormer')
ax1.scatter(metrics, time_values_FEDformer, marker='o', color='grey', label='FEDformer')
ax1.scatter(metrics, time_values_Autoformer, marker='o', color='orange', label='Autoformer')
ax1.scatter(metrics, time_values_Informer, marker='o', color='blue', label='Informer')
ax1.scatter(metrics, time_values_LogTrans, marker='o', color='green', label='LogTrans')
ax1.scatter(metrics, time_values_Reformer, marker='o', color='purple', label='Reformer')
ax1.set_ylabel("Time (s)",size=14)
ax1.set_xlabel("Dataset",size=14)
ax1.set_title("Test set running time each epoch on eight datasets")

#fig.legend(['MAE-Periormer', 'MAE-Autoformer','MAE-Informer','MAE-LogTrans','MAE-Reformer'],loc='upper right',bbox_to_anchor=(1.14,0.879))#bbox_to_anchor=(0.13,0.88))#bbox_to_anchor=(0.13,0.88))
fig.legend(['Periormer','FEDformer', 'Autoformer', 'Informer', 'LogTrans', 'Reformer'], loc='upper left',
           bbox_to_anchor=(0.13, 0.88),prop={'size': 12})
fig.savefig('Test set running time each epoch on eight datasets.pdf',format='pdf')
plt.show()
